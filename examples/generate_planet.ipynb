# %% [markdown]
# ### Import the client

# %%
from planet_generator import Client

# %% [markdown]
# ### Create the client

# %%
planet_api = Client.from_api_key(
    api_key="YOUR API KEY HERE"
)

# %% [markdown]
# ### Check if the API is up

# %%
planet_api.get_status()
# Out:
# StatusMessage(status_code=200, message='Planet API is up and running !')

# %% [markdown]
# ### Generate a planet

# %%
planet = planet_api.get_planet()
sprite = planet.sprite.get_image(apply_masks=True)

# %%
sprite
# Out:
# <PIL.Image.Image image mode=RGBA size=1080x1080>
